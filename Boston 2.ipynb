# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn

# %%
df=pd.read_csv('D:\Gandhi\Machine Learning\Datasets\Boston\housing.csv')
df.head()
# Out:
#    0.00632  18.00   2.310  0  0.5380  6.5750  65.20  4.0900   1  296.0  15.30 396.90   4.98  24.00
# 0   0.02731   0.00   7.070  0  0.4690  6.4210  78...
# 1   0.02729   0.00   7.070  0  0.4690  7.1850  61...
# 2   0.03237   0.00   2.180  0  0.4580  6.9980  45...
# 3   0.06905   0.00   2.180  0  0.4580  7.1470  54...
# 4   0.02985   0.00   2.180  0  0.4580  6.4300  58...

# %%
column_names=['CRIME', 'ZONE', 'INDUS', 'CHAS', 'NOX', 'ROOM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
df=pd.read_csv('D:\Gandhi\Machine Learning\Datasets\Boston\housing.csv',header=None,names=column_names,delim_whitespace=True)
df.head()
# Out:
#      CRIME  ZONE  INDUS  CHAS    NOX   ROOM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
df.describe()
# Out:
#             CRIME        ZONE       INDUS        CHAS         NOX        ROOM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677082   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
df.hist(bins=20,figsize=(15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001982601CC18>,
# ...
#       dtype=object)

# %%
df.boxplot(figsize=(15,15))

# %%
df.CRIME.describe()
# Out:
# count    506.000000
# mean       3.613524
# std        8.601545
# min        0.006320
# 25%        0.082045
# 50%        0.256510
# 75%        3.677082
# max       88.976200
# Name: CRIME, dtype: float64

# %%
df.CRIME.hist()

# %%
crime_min_cutoff=3.613524-3*8.601545
crime_max_cutoff=3.613524+3*8.601545
print(crime_min_cutoff)
print(crime_max_cutoff)
# Out:
# -22.191111
# 29.418158999999996

# %%
df=df.drop(df[df.CRIME>29.418189999].index)

# %%
df.shape
# Out:
# (498, 14)

# %%
df.ZONE.describe()
# Out:
# count    498.000000
# mean      11.546185
# std       23.464449
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%       12.500000
# max      100.000000
# Name: ZONE, dtype: float64

# %%
df.ZONE.hist()

# %%
zone_min_cutoff=11.546185-3*23.464449
zone_max_cutoff=11.546185+3*23.464449
print(zone_min_cutoff)
print(zone_max_cutoff)
# Out:
# -58.84716199999999
# 81.93953199999999

# %%
df=df.drop(df[df.ZONE>81.9395919999].index)

df.shape
# Out:
# (484, 14)

# %%
df.INDUS.hist()

# %%
df.INDUS.describe()
# Out:
# count    484.000000
# mean      11.282376
# std        6.782492
# min        0.460000
# 25%        5.320000
# 50%        9.690000
# 75%       18.100000
# max       27.740000
# Name: INDUS, dtype: float64

# %%
df.CHAS.hist()

# %%
df.B.hist()

# %%
df.B.describe()
# Out:
# count    484.000000
# mean     358.160764
# std       88.205368
# min        0.320000
# 25%      375.300000
# 50%      391.385000
# 75%      396.250000
# max      396.900000
# Name: B, dtype: float64

# %%
b_min_cutoff=358.160764-3*88.205368
b_max_cutoff=358.160764+3*88.205368
print(b_min_cutoff)
print(b_max_cutoff)
# Out:
# 93.54465999999996
# 622.7768679999999

# %%
df=df.drop(df[df.B<93.54465999].index)
df.shape
# Out:
# (459, 14)

# %%
df.LSTAT.hist()

# %%
df.LSTAT.describe()
# Out:
# count    459.000000
# mean      12.264771
# std        6.749363
# min        1.730000
# 25%        6.970000
# 50%       10.970000
# 75%       16.205000
# max       37.970000
# Name: LSTAT, dtype: float64

# %%
lst_min_cutoff=12.264771-3*6.749363
lst_max_cutoff=12.264771+3*6.749363
print(lst_min_cutoff)
print(lst_max_cutoff)
# Out:
# -7.983318000000001
# 32.51286

# %%
df=df.drop(df[df.LSTAT>32.51286].index)
df.shape
# Out:
# (456, 14)

# %%
df.MEDV.hist()

# %%
df.MEDV.describe()
# Out:
# count    456.000000
# mean      22.964693
# std        8.686144
# min        5.600000
# 25%       17.950000
# 50%       21.600000
# 75%       25.000000
# max       50.000000
# Name: MEDV, dtype: float64

# %%
med_min_cutoff=22.964693-3*8.686144
med_max_cutoff=22.964693+3*8.686144
print(med_min_cutoff)
print(med_max_cutoff)
# Out:
# -3.093739000000003
# 49.02312500000001

# %%
df=df.drop(df[df.MEDV>49.02312500].index)
df.shape
# Out:
# (442, 14)

# %%
plt.figure(figsize = (15,12))
sn.heatmap(data=df.corr(),annot=True,linewidths=.8,cmap='Blues')

# %%
##It’s a good practice to remove correlated variables during feature selection.b

# %%
sn.pairplot(df,x_vars=['CRIME','ZONE','INDUS'],y_vars=['MEDV'],kind='reg',height=6)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sn.pairplot(df,x_vars=['NOX','ROOM','AGE'],y_vars=['MEDV'],kind='reg',height=6)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sn.pairplot(df,x_vars=['DIS','RAD','TAX'],y_vars=['MEDV'],kind='reg',height=6)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sn.pairplot(df,x_vars=['PTRATIO','B','LSTAT'],y_vars=['MEDV'],kind='reg',height=6)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
plt.figure(figsize=(12,12))
sn.heatmap(data=df.corr(),annot=True,cmap='Blues')

# %%
df.head()
# Out:
#      CRIME  ZONE  INDUS  CHAS    NOX   ROOM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
df.shape
# Out:
# (442, 14)

# %%
x=df.drop(['MEDV'],axis='columns')
y=df.MEDV

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn import linear_model
reg=linear_model.LinearRegression()

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
y_pred=reg.predict(x_test)

# %%
reg.score(x_test,y_test)
# Out:
# 0.6595205001128593

# %%
from sklearn.metrics import mean_squared_error
mse=mean_squared_error(y_test,y_pred)
mse
# Out:
# 14.804754459080774

# %%
df.boxplot(figsize=(12,12))

# %%
df.B.hist()

# %%
df.B.describe()
# Out:
# count    442.000000
# mean     375.389163
# std       47.784494
# min       96.730000
# 25%      377.817500
# 50%      392.315000
# 75%      396.900000
# max      396.900000
# Name: B, dtype: float64

# %%
maxB=375.389163+3*47.784494
minB=375.389163-3*47.784494
print("max=",maxB)
print("min=",minB)
# Out:
# max= 518.742645
# min= 232.03568099999998

# %%
df=df.drop(df[df.B<232.035].index)
df.shape
# Out:
# (430, 14)

# %%
x=df.drop(['MEDV'],axis='columns')
y=df.MEDV

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn import linear_model
reg=linear_model.LinearRegression()

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
y_pred=reg.predict(x_test)

# %%
reg.score(x_test,y_test)
# Out:
# 0.7795650047776589

# %%
from sklearn.metrics import mean_squared_error
mse1=mean_squared_error(y_test,y_pred)
mse1
# Out:
# 13.948833220174738

# %%
rmse=np.sqrt(mse)
rmse
# Out:
# 3.847694694109809

# %%
df.boxplot()

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor(n_estimators=200,random_state=0)

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=200, n_jobs=1,
#            oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
y1_predict=rf.predict(x_test)

# %%
rf.score(x_test,y_test)
# Out:
# 0.8644361567129132

# %%
mse=mean_squared_error(y_test,y_pred)

# %%
mse
# Out:
# 13.948833220174738

# %%
rmse=np.sqrt(mse)
rmse
# Out:
# 3.7348136794457014

# %%
w=([[0.06905,0.0,2.18,0,0.458,7.147,54.2,6.0622,3,222.0,18.7,396.90,5.33]])
reg.predict(w)
# Out:
# array([28.14773808])

# %%
rf.predict(w)
# Out:
# array([35.6255])

# %%
q=[[0.00632,18.0,2.31,0,0.538,6.575,65.2,4.0900,1,296.0,15.3,396.90,4.98]]
reg.predict(q)
# Out:
# array([28.73425532])

# %%
rf.predict(q)
# Out:
# array([25.53])
